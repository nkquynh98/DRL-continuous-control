# %%
import torch
import random
from collections import deque
import matplotlib.pyplot as plt
import sys
import os
import numpy as np
# %matplotlib inline

# %%
scores = torch.load('score.pth')
score_2 = []
score_temp = deque(maxlen=100)
for score in scores:
    score_temp.append(score)
    score_2.append(np.average(score_temp))
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.plot(np.arange(1, len(scores)+1), score_2)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
print(np.max(score))
# Out:
# 28.29949936745688
