# %%
import torch
import random
from collections import deque
import matplotlib.pyplot as plt
import sys
import os
import numpy as np
# %matplotlib inline

# %%
scores = torch.load('score.pth')
score_2 = []
score_temp = deque(maxlen=100)
for score in scores:
    score_temp.append(score)
    score_2.append(np.average(score_temp))
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label = 'Score')
plt.plot(np.arange(1, len(scores)+1), score_2,label = 'Average Score')
plt.legend()
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-60ee21370469> in <module>
#       8 ax = fig.add_subplot(111)
#       9 plt.plot(np.arange(1, len(scores)+1), scores, label = 'Score')
# ---> 10 plt.plot(np.arange(1, len(scores)+1), score_2, lbel = 'Average Score')
#      11 plt.legend()
#      12 plt.ylabel('Score')
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
#     418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 419                 for j in range(max(ncx, ncy))]
#     420
#     421
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
#     418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 419                 for j in range(max(ncx, ncy))]
#     420
#     421
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     388         # update kwargs before updating data to give the caller a
#     389         # chance to init axes (and hence unit support)
# --> 390         self.update(kwargs)
#     391         self.pickradius = pickradius
#     392         self.ind_offset = 0
#
# ~/anaconda3/envs/drlnd/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'lbel'

# %%
print(np.max(score))
# Out:
# 28.29949936745688
